# %%
import pandas as pd 
import numpy as np

# %%
cols_needed = ['loan_amnt','term','int_rate','installment','grade','sub_grade',
               'purpose','issue_d','emp_length','home_ownership','annual_inc',
               'verification_status','addr_state','dti','earliest_cr_line',
               'fico_range_low','fico_range_high','open_acc','pub_rec',
               'revol_bal','revol_util','total_acc','loan_status']

# %%
fin = pd.read_csv("Data/accepted_2007_to_2018Q4.csv.gz", compression='gzip', usecols=cols_needed)

# %%
fin.shape
# Out:
# (2260701, 23)

# %%
fin.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Data columns (total 23 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   loan_amnt            float64
#  1   term                 str
#  2   int_rate             float64
#  3   installment          float64
#  4   grade                str
#  5   sub_grade            str
#  6   emp_length           str
#  7   home_ownership       str
#  8   annual_inc           float64
#  9   verification_status  str
#  10  issue_d              str
#  11  loan_status          str
#  12  purpose              str
#  13  addr_state           str
#  14  dti                  float64
#  15  earliest_cr_line     str
#  16  fico_range_low       float64
#  17  fico_range_high      float64
#  18  open_acc             float64
#  19  pub_rec              float64
#  20  revol_bal            float64
#  21  revol_util           float64
#  22  total_acc            float64
# dtypes: float64(12), str(11)
# ...

# %%
fin.isnull().sum()
# Out:
# loan_amnt                  33
# term                       33
# int_rate                   33
# installment                33
# grade                      33
# sub_grade                  33
# emp_length             146940
# home_ownership             33
# annual_inc                 37
# verification_status        33
# issue_d                    33
# loan_status                33
# purpose                    33
# addr_state                 33
# dti                      1744
# earliest_cr_line           62
# fico_range_low             33
# fico_range_high            33
# open_acc                   62
# pub_rec                    62
# revol_bal                  33
# revol_util               1835
# total_acc                  62
# dtype: int64

# %%
df = fin.copy()

# %%
df.shape
# Out:
# (2260701, 23)

# %%
fin[fin.duplicated()]
# Out:
#          loan_amnt term  int_rate  installment grade sub_grade emp_length  \
# 421096         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 528961         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 528962         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 651664         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 651665         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 749520         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 749521         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 877716         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 877717         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 983169         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 983170         NaN  NaN       NaN          NaN   NaN       NaN        NaN
# 1117058        NaN  NaN       NaN          NaN   NaN       NaN        NaN
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (2260669, 23)

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0     3600.0   36 months     13.99       123.03     C        C4  10+ years
# 1    24700.0   36 months     11.99       820.28     C        C1  10+ years
# 2    20000.0   60 months     10.78       432.66     B        B4  10+ years
# 3    35000.0   60 months     14.85       829.90     C        C5  10+ years
# 4    10400.0   60 months     22.45       289.91     F        F1    3 years
#
#   home_ownership  annual_inc verification_status  ... addr_state    dti  \
# 0       MORTGAGE     55000.0        Not Verified  ...         PA   5.91
# 1       MORTGAGE     65000.0        Not Verified  ...         SD  16.06
# 2       MORTGAGE     63000.0        Not Verified  ...         IL  10.78
# 3       MORTGAGE    110000.0     Source Verified  ...         NJ  17.06
# 4       MORTGAGE    104433.0     Source Verified  ...         PA  25.37
#
#   earliest_cr_line fico_range_low  fico_range_high open_acc  pub_rec  \
# ...

# %%
df.dropna(subset=['loan_amnt'],inplace= True)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_length             146907
# home_ownership              0
# annual_inc                  4
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# addr_state                  0
# dti                      1711
# earliest_cr_line           29
# fico_range_low              0
# fico_range_high             0
# open_acc                   29
# pub_rec                    29
# revol_bal                   0
# revol_util               1802
# total_acc                  29
# dtype: int64

# %%
df['pub_rec'].fillna(0,inplace= True)
df['open_acc'].fillna(0,inplace= True)
df['total_acc'].fillna(0,inplace= True)
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_372\714700416.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['pub_rec'].fillna(0,inplace= True)
# ...
